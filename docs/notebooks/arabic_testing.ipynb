# %%
# pip install ipywidgets
# !pip install pyarabic
# Out:
# Requirement already satisfied: pyarabic in c:\users\yahya\my_projects\stream_env\lib\site-packages (0.6.15)
# Requirement already satisfied: six>=1.14.0 in c:\users\yahya\my_projects\stream_env\lib\site-packages (from pyarabic) (1.16.0)

# %%
from pyarabic.araby import strip_tashkeel, strip_tatweel
from pyarabic.normalize import normalize_hamza, normalize_lamalef

# %%
import unicodedata

# %%
import nltk
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\yahya\my_projects\stream_env\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# First import TMDataset
from stream_topic.utils.dataset import TMDataset
from stream_topic.models import KmeansTM
from stream_topic.preprocessor._preprocessor import TextPreprocessor
from stream_topic.preprocessor.arabic_preprocessing import ArabicPreprocessor
from stream_topic.models.ArabicKmeansTM import ArabicKmeansTM

# Initialize dataset
dataset = TMDataset()

# Test if it works
print("Dataset initialized successfully")
# Out:
# Dataset initialized successfully

# %%
from pathlib import Path



# Load Arabic dataset
print("Loading Arabic dataset...")
dataset.fetch_dataset("Arabic_News")

# Print basic information
print("\nDataset Info:")
print(f"Number of documents: {len(dataset.dataframe)}")
print(f"Available topics: {dataset.dataframe['labels'].unique()}")
# Out:
# 2024-11-24 20:52:50.699 | INFO     | stream_topic.utils.dataset:fetch_dataset:230 - Fetching dataset: Arabic_News
# 2024-11-24 20:52:50.702 | INFO     | stream_topic.utils.dataset:fetch_dataset:261 - Processing Arabic dataset from c:\users\yahya\my_projects\stream\stream_topic\stream_topic_data\arabic_datasets\Arabiya
# 2024-11-24 20:52:50.702 | DEBUG    | stream_topic.utils.dataset:_load_arabic_dataset:134 - Tried path (not found): c:\users\yahya\my_projects\stream\data\arabic_datasets\arabic_news\Arabiya
# 2024-11-24 20:52:50.703 | DEBUG    | stream_topic.utils.dataset:_load_arabic_dataset:134 - Tried path (not found): c:\users\yahya\my_projects\stream\stream_topic\stream_topic_data\arabic_datasets\Arabiya
# 2024-11-24 20:52:50.703 | DEBUG    | stream_topic.utils.dataset:_load_arabic_dataset:134 - Tried path (not found): data\arabic_datasets\arabic_news\Arabiya
# 2024-11-24 20:52:50.704 | DEBUG    | stream_topic.utils.dataset:_load_arabic_dataset:134 - Tried path (not found): C:\Users\yahya\my_projects\STREAM\docs\notebooks\data\arabic_datasets\arabic_news\Arabiya
# 2024-11-24 20:52:50.705 | INFO     | stream_topic.utils.dataset:_load_arabic_dataset:131 - Found valid dataset path: C:\Users\yahya\my_projects\STREAM\stream_topic\data\arabic_datasets\arabic_news\Arabiya
# 2024-11-24 20:52:50.705 | INFO     | stream_topic.utils.dataset:_load_arabic_dataset:147 - Loading data from: C:\Users\yahya\my_projects\STREAM\stream_topic\data\arabic_datasets\arabic_news\Arabiya
# 2024-11-24 20:52:50.705 | INFO     | stream_topic.utils.dataset:_load_arabic_dataset:156 - Processing topic: Culture
# Loading Arabic dataset...
# 2024-11-24 20:53:09.603 | INFO     | stream_topic.utils.dataset:_load_arabic_dataset:156 - Processing topic: Finance
# 2024-11-24 20:54:50.682 | INFO     | stream_topic.utils.dataset:_load_arabic_dataset:156 - Processing topic: Medical
# 2024-11-24 20:55:02.922 | INFO     | stream_topic.utils.dataset:_load_arabic_dataset:156 - Processing topic: Politics
# 2024-11-24 20:55:17.286 | INFO     | stream_topic.utils.dataset:_load_arabic_dataset:156 - Processing topic: Sports
# 2024-11-24 20:56:38.937 | INFO     | stream_topic.utils.dataset:_load_arabic_dataset:156 - Processing topic: Tech
# 2024-11-24 20:56:54.961 | INFO     | stream_topic.utils.dataset:_load_arabic_dataset:176 - Successfully processed 71222 files with 0 errors
# 2024-11-24 20:56:54.962 | INFO     | stream_topic.utils.dataset:_load_arabic_dataset:177 - Found 6 unique topics
# 2024-11-24 20:56:56.208 | INFO     | stream_topic.utils.dataset:_load_arabic_dataset:193 - Cached preprocessed dataset to c:\users\yahya\my_projects\stream\cache\preprocessed_datasets\arabic_news.parquet
# 2024-11-24 20:56:56.217 | INFO     | stream_topic.utils.dataset:fetch_dataset:277 - Successfully loaded Arabic dataset 'Arabic_News' with 71222 documents
# Dataset Info:
# Number of documents: 71222
# Available topics: ['Culture' 'Finance' 'Medical' 'Politics' 'Sports' 'Tech']

# %%
# Set the language and preprocess
dataset.language = "ar"  # Set language first
dataset.preprocess()  # Don't pass language here since it's already set

# Print some info
print(f"Number of documents: {len(dataset.dataframe)}")
print(f"Sample preprocessed text: {dataset.dataframe['text'].iloc[0][:200]}")
# Out:
# Found 71222 documents to preprocess
# Processing text: وصف الفنان الكويتي أحمد إيراج المسلسل الإماراتي ال...
# Error preprocessing text: name 'normalize_tah_marbota' is not defined
# Processing text: يزور المنتج رزاق الموسوي هذه الأيام مدينة كان، جنو...
# Error preprocessing text: name 'normalize_tah_marbota' is not defined
# Processing text: أكد الفنان عزت أبوعوف، رئيس مهرجان القاهرة السينما...
# Error preprocessing text: name 'normalize_tah_marbota' is not defined
# Processing text: غيب الموت مساء السبت، الفنان المصري محمود الدسوقي،...
# Error preprocessing text: name 'normalize_tah_marbota' is not defined
# Processing text: فاز الفيلم الإيراني "الصورة الأخيرة لذكرى" بالجائز...
# Error preprocessing text: name 'normalize_tah_marbota' is not defined
# Processing text: تواصل الفنانة الكبيرة ماجدة الصباحي على قدم وساق أ...
# Error preprocessing text: name 'normalize_tah_marbota' is not defined
# Processing text: أعلنت مجلة فوربس الاثنين، أن نجمة موسيقى البوب الأ...
# Error preprocessing text: name 'normalize_tah_marbota' is not defined
# Processing text: للعام الرابع على التوالي، يطل الفنان المصري يوسف ا...
# Error preprocessing text: name 'normalize_tah_marbota' is not defined
# Processing text: بعد نجاح أجزائه السابقة، يعود #مسلسل #ذباح_غليص بج...
# Error preprocessing text: name 'normalize_tah_marbota' is not defined
# Processing text: عقب تقديم الجزء الأول من مسلسل "الجماعة"، الذي يتن...
# Error preprocessing text: name 'normalize_tah_marbota' is not defined
# Processing text: وقع اختيار الفنان تامر حسني على الطفل أحمد السيسي،...
# Error preprocessing text: name 'normalize_tah_marbota' is not defined
# Processing text: عبرت الفنانة الكويتية غدير السبتي عن سعادتها الغام...
# Error preprocessing text: name 'normalize_tah_marbota' is not defined
# Processing text: الدراما الرمضانية هذا العام، ستعيد ثنائيات افتقدها...
# Error preprocessing text: name 'normalize_tah_marbota' is not defined
# Processing text: طوله 33 سنتيمتراً أما وزنه ف 3,85 كيلوغرامات ويحمل...
# Error preprocessing text: name 'normalize_tah_marbota' is not defined
# Processing text: يستعد الفنان راغب علامة للبدء بتسجيل عدد من أغنيات...
# Error preprocessing text: name 'normalize_tah_marbota' is not defined
# Processing text: على خشبة المسرح الكبير بدار الأوبرا المصرية، أقيم ...
# Error preprocessing text: name 'normalize_tah_marbota' is not defined
# Processing text: أكدت الفنانة البحرينية ريم ارحمه أنها تواصل هذه ال...
# Error preprocessing text: name 'normalize_tah_marbota' is not defined
# Processing text: مع متابعة قطاع كبير من الجمهور للأعمال الدرامية ال...
# Error preprocessing text: name 'normalize_tah_marbota' is not defined
# Processing text: توفي صباح الأحد، الفنان عبدالرحمن قيروش الملقب "با...
# Error preprocessing text: name 'normalize_tah_marbota' is not defined
# Processing text: حالة رواج تشهدها دور العرض المصرية في الوقت الحالي...
# Error preprocessing text: name 'normalize_tah_marbota' is not defined
# Processing text: أعلن في مدينة كان جنوب فرنسا وقبل يوم واحد من انطل...
# Error preprocessing text: name 'normalize_tah_marbota' is not defined
# Processing text: يستضيف #المتحف_العربي_الأميركي في مدينة ديربورن في...
# Error preprocessing text: name 'normalize_tah_marbota' is not defined
# Processing text: أ

# Error preprocessing text: name 'normalize_tah_marbota' is not defined
# Processing text: بدأت منصة التواصل الاجتماعي #فيسبوك إتاحة قسمها ال...
# Error preprocessing text: name 'normalize_tah_marbota' is not defined
# Number of documents: 71222
# Sample preprocessed text: وصف الفنان الكويتي أحمد إيراج المسلسل الإماراتي الجديد "خيانة وطن" بأنه تجربة استثنائية في الدراما الخليجية، وأنه إضافة لرصيد الدراما الإماراتية والخليجية على حد سواء. وأضاف أحمد إيراج لـ"العربية.نت"

# %%
# After loading dataset but before training
print("Sample of preprocessed text:")
print(dataset.dataframe['text'].iloc[0])
print("\nUnique labels:", dataset.dataframe['labels'].unique())
print("\nNumber of documents per label:")
print(dataset.dataframe['labels'].value_counts())
# Out:
# Sample of preprocessed text:
# وصف الفنان الكويتي أحمد إيراج المسلسل الإماراتي الجديد "خيانة وطن" بأنه تجربة استثنائية في الدراما الخليجية، وأنه إضافة لرصيد الدراما الإماراتية والخليجية على حد سواء. وأضاف أحمد إيراج لـ"العربية.نت" بشأن العمل قائلا: إنه يذهب إلى مناطق جديدة في الدراما، حيث كشف الخلايا الإرهابية والمتطرفة عبر عرض للتحقيقات التي تمت معهم إثر القبض عليهم في دولة الإمارات العربية المتحدة. وأضاف أن العمل يفضح ممارسات العديد من المنظمات الإرهابية والمتطرفة وسبل مواجهتها بالتكاتف والتلاحم بين أبناء ودول المنطقة. وأعرب إيراج عن سعادته بردود الأفعال التي يحصدها العمل ومنذ اليوم الأول للشهر الفضيل. يذكر أن مسلسل خيانة وطن سيناريو وحوار الكاتب القدير إسماعيل عبدالله عن رواية "ريتاج" لحمد الحمادي وإخراج الفنان أحمد يعقوب المقلة وبطولة حشد من نجوم الدراما في دول مجلس التعاون، منهم جاسم النبهان وحبيب غلوم وهيفاء حسين وفاطمة الحوسني وغيرهم. ويشارك الفنان أحمد إيراج في الدورة الرمضانية أيضا من خلال المسلسل الكوميدي الاجتماعي "المحتالة" مع الفنانة هدى حسين وجاسم النبهان وعبدالرحمن العقل وسحر حسين وهيا الشعيبي ومرام، من إخراج محمد العوالي، كما يطل من خلال مسلسل "أحلام على ورق" والذي تم تصويره في أبوظبي. وعن جديده المسرحي قال: ستكون عيديتي للجمهور الحبيب مسرحية "البيدر"، وهي عمل تراثي اجتماعي سياسي من بطولة النجم سعد الفرج الذي يمثل التعاون معه إضافة حقيقية لرصيدي وتجربتي، كما يشارك في العمل كم كبير من النجوم وستنطلق عروض المسرحية اعتبارا من أول أيام عيد الفطر المبارك على صالة مسرح الدسمة.
#
# Unique labels: ['Culture' 'Finance' 'Medical' 'Politics' 'Sports' 'Tech']
#
# Number of documents per label:
# labels
# Finance     30068
# Sports      23058
# Culture      5619
# Tech         4410
# Politics     4352
# Medical      3715
# Name: count, dtype: int64

# %% [markdown]
# ##### 🚀 Model fitting
# **For Arabic Data**

# %%
model = ArabicKmeansTM(num_topics=5)
model.fit(dataset)
# Out:
# 2024-11-24 20:57:30.353 | INFO     | stream_topic.models.ArabicKmeansTM:fit:302 - Training ArabicKmeansTM
# 2024-11-24 20:57:30.354 | INFO     | stream_topic.models.ArabicKmeansTM:_prepare_embeddings:266 - Preparing document embeddings...
# C:\Users\yahya\my_projects\stream_env\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning:
#
# `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
# Batches:   0%|          | 0/2226 [00:00<?, ?it/s]
# 2024-11-24 21:16:01.538 | INFO     | stream_topic.models.ArabicKmeansTM:_prepare_embeddings:284 - Document embeddings prepared successfully
# 2024-11-24 21:16:01.553 | INFO     | stream_topic.models.abstract_helper_models.base:dim_reduction:196 - --- Reducing dimensions ---
# 2024-11-24 21:16:52.966 | INFO     | stream_topic.models.ArabicKmeansTM:fit:366 - Training completed successfully

# %%
# Get and display topics

topics = model.get_topics()
print("\nExtracted Topics:")
for idx, topic in enumerate(topics):
    print(f"\nTopic {idx}:")
    print(", ".join(topic[:10]))  # Print top 10 words
# Out:
# Extracted Topics:
#
# Topic 0:
# أكد, أعلن, أعلنت, القدم, السعودي, النادي, الفريق, الاتحاد, رئيس, الشركة
#
# Topic 1:
# قال, إن, قالت, النفط, وأضاف, مصر, برميل, إنه, وقال, مليار
#
# Topic 2:
# السوق, نحو, أسعار, النفط, دولار, مستوى, السعودية, تراجع, شركة, بنسبة
#
# Topic 3:
# أمام, كان, وفي, الفريق, لم, وهو, كما, كل, ذلك, مباراة
#
# Topic 4:
# درهم, بقيمة, مبايعة, مبايعات, منطقة, مليون, الدقيقة, بتسجيلها, حققت, حقق

# %% [markdown]
# ##### ✅ Evaluation

# %%
from stream_topic.metrics import ISIM, INT, ISH,Expressivity, NPMI

metric = ISIM()
metric.score(topics)
# Out:
# 0.7524140000343322

# %%
# Scores for each topic 
metric.score_per_topic(topics)
# Out:
# {'أكد, أعلن, أعلنت, القدم, السعودي': 0.8747699856758118,
#  'قال, إن, قالت, النفط, وأضاف': 0.7130399942398071,
#  'السوق, نحو, أسعار, النفط, دولار': 0.626259982585907,
#  'أمام, كان, وفي, الفريق, لم': 0.7487900257110596,
#  'درهم, بقيمة, مبايعة, مبايعات, منطقة': 0.7509499788284302}

# %%
from octis.evaluation_metrics.diversity_metrics import TopicDiversity

model_output = {"topics": model.get_topics(), "topic-word-matrix": model.get_beta(), "topic-document-matrix": model.get_theta()}

metric = TopicDiversity(topk=10) # Initialize metric
topic_diversity_score = metric.score(model_output)

# %% [markdown]
# ##### 🖼️ Visualization

# %%
from stream_topic.visuals import visualize_topic_model,visualize_topics
visualize_topic_model(
    model, 
    reduce_first=True, 
    port=8051,
    )
# Out:
# C:\Users\yahya\my_projects\stream_env\lib\site-packages\umap\umap_.py:2437: UserWarning:
#
# n_neighbors is larger than the dataset size; truncating to X.shape[0] - 1
#
# C:\Users\yahya\my_projects\stream_env\lib\site-packages\dash\dash.py:2282: DeprecationWarning:
#
# Dash.run_server is deprecated and will be removed in Dash 3.0
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8051/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ##### 🔍 Hyperparameter optimization

# %%
model.optimize_and_fit(
    dataset,
    min_topics=2,
    max_topics=20,
    criterion="aic",
    n_trials=20,
)

# %%
nltk.download('stopwords', quiet=True)
# Out:
# True

# %%
x = nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\yahya\my_projects\stream_env\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 x.tolist()
#
# AttributeError: 'bool' object has no attribute 'tolist'
